# %% [markdown]
# # Unit 2: Fisheries Collapse Module Overview
#
# This module will focus on examining a crucial global issue and important scientific debate about the state of global fisheries.  In this module we will seek to reproduce some of the most widely cited examples of species collapse ever, and examine the evidence behind an influential and widely cited paper on global fisheries, [Worm et al 2006](http://doi.org/10.1126/science.1132294).  However, rather than use the limited data available to Boris Worm and colleagues in 2006, we will be drawing from the best and most recent stock asssement data available today to see how those patterns have faired.
#
# In this module we will also begin to master one of the most important concepts in data science: manipulation of tabular data using relational database concepts. Instead of working with independent data.frames, we will be working with a large relational database which contains many different tables of different sizes and shapes, but that all all related to each other through a series of different ids.

# %% [markdown]
# ## The Database
#
# We will use data from the RAM Legacy Stock Assessment Database.  In order to better introduce some important emerging technologies, we will be accessing these data directly from a relatively new platform that is now playing a key role in data sharing in machine learning communities, with the memorable name, HuggingFace.  We will be streaming data from <https://huggingface.co/datasets/cboettig/ram_fisheries/tree/main/v4.65>.  We will have more to say about this approach as we progress.

# %% [markdown]
# ## Researcher Spotlight: Daniel Pauly
#
# Science is done by real people.  There are many influential and colorful characters in the global fisheries debate.  I want to highlight Professor Pauly not just because he is so famous, but as an early believer in Open Science and Data Science, before we had either of those words.  His contributions in making fisheries data more open were ground breaking for their time.  I'm also indebted to Professor Pauly whom I had the privilege to meet when I was a junior scientist who had only recently released one of my first software packages, aimed at making data from FishBase more accessible. Academic researchers are typically defined by scientific publications, not software, so I was shocked that Pauly already knew of my software package, and that he encouraged me to continue developing software.  Even today that is not common advice, but I believed him, and it's probably a good reason I am where I am today.  Scientific textbooks and courses are often critiqued for failing to recognize the contributions of those from minority backgrounds, but as the texts are written on global change ecology, I think none will omit the works for Professor Pauly.

# %% [markdown]
# ## Science Introduction
#
# Background abbreviated documentary, features many of the leading authors on both sides https://vimeo.com/44104959

# %%
import ibis
from ibis import _
import ibis.selectors as s
import seaborn.objects as so

# %%
con = ibis.duckdb.connect()
base = "https://huggingface.co/datasets/cboettig/ram_fisheries/tree/main/v4.65"
#area = base + "area.csv"

tsmetrics = con.read_csv("https://huggingface.co/datasets/cboettig/ram_fisheries/resolve/main/v4.65/tsmetrics.csv")
timeseries = con.read_csv("https://huggingface.co/datasets/cboettig/ram_fisheries/resolve/main/v4.65/timeseries.csv")
stock = con.read_csv("https://huggingface.co/datasets/cboettig/ram_fisheries/resolve/main/v4.65/stock.csv")
assessment = con.read_csv("https://huggingface.co/datasets/cboettig/ram_fisheries/resolve/main/v4.65/assessment.csv")
area = con.read_csv("https://huggingface.co/datasets/cboettig/ram_fisheries/resolve/main/v4.65/area.csv")

area.head().execute()
# Out:
#      country areatype areacode                             areaname  \
# 0  Argentina      CFP    ARG-N                   Northern Argentina
# 1  Argentina      CFP    ARG-S                   Southern Argentina
# 2  Australia     AFMA  CASCADE                      Cascade Plateau
# 3  Australia     AFMA     EAUS                    Eastern Australia
# 4  Australia     AFMA      ESE  Eastern half of Southeast Australia
#
#   alternateareaname                  areaid
# 0                NA     Argentina-CFP-ARG-N
# 1                NA     Argentina-CFP-ARG-S
# 2                NA  Australia-AFMA-CASCADE
# 3                NA     Australia-AFMA-EAUS
# 4                NA      Australia-AFMA-ESE

# %%
#pull up tables - 

stock.head().execute
# Out:
# <bound method Expr.execute of r0 := DatabaseTable: ibis_read_csv_sv7fpoi2gzhpjghsiz3wtjfdqe
#   stockid         string
#   tsn             int64
#   scientificname  string
#   commonname      string
#   areaid          string
#   stocklong       string
#   region          string
#   primary_country string
#   primary_FAOarea int64
#   ISO3_code       string
#   GRSF_uuid       string
#   GRSF_areaid     string
#   inmyersdb       int64
#   myersstockid    string
#   state           string
#
# Limit[r0, n=5]>

# %%
area.head().execute()
# Out:
#      country areatype areacode                             areaname  \
# 0  Argentina      CFP    ARG-N                   Northern Argentina
# 1  Argentina      CFP    ARG-S                   Southern Argentina
# 2  Australia     AFMA  CASCADE                      Cascade Plateau
# 3  Australia     AFMA     EAUS                    Eastern Australia
# 4  Australia     AFMA      ESE  Eastern half of Southeast Australia
#
#   alternateareaname                  areaid
# 0                NA     Argentina-CFP-ARG-N
# 1                NA     Argentina-CFP-ARG-S
# 2                NA  Australia-AFMA-CASCADE
# 3                NA     Australia-AFMA-EAUS
# 4                NA      Australia-AFMA-ESE

# %%
stock.filter(_.commonname == "Atlantic cod").execute()
#timeseries.filter(_.stockid == "COD1ABCDE").head().execute()
#tsmetrics.filter(_.tscategory == "CATCH or LANDINGS").select(_.tslong, _.tsunique,
# Out:
#              stockid     tsn scientificname    commonname  \
# 0          COD1ABCDE  164712   Gadus morhua  Atlantic cod
# 1          COD1F-XIV  164712   Gadus morhua  Atlantic cod
# 2             COD1IN  164712   Gadus morhua  Atlantic cod
# 3           COD2J3KL  164712   Gadus morhua  Atlantic cod
# 4              COD3M  164712   Gadus morhua  Atlantic cod
# 5             COD3NO  164712   Gadus morhua  Atlantic cod
# 6          COD3Pn4RS  164712   Gadus morhua  Atlantic cod
# 7             COD3Ps  164712   Gadus morhua  Atlantic cod
# 8            COD4TVn  164712   Gadus morhua  Atlantic cod
# 9            COD4VsW  164712   Gadus morhua  Atlantic cod
# 10             COD4X  164712   Gadus morhua  Atlantic cod
# 11          COD4X5Yb  164712   Gadus morhua  Atlantic cod
# 12           COD5Zjm  164712   Gadus morhua  Atlantic cod
# 13         CODBA2224  164712   Gadus morhua  Atlantic cod
# 14         CODBA2532  164712   Gadus morhua  Atlantic cod
# 15          CODFABNK  164712   Gadus morhua  Atlantic cod
# 16           CODFAPL  164712   Gadus morhua  Atlantic cod
# 17             CODGB  164712   Gadus morhua  Atlantic cod
# 18            CODGOM  164712   Gadus morhua  Atlantic cod
# 19            CODICE  164712   Gadus morhua  Atlantic cod
# 20  CODIIIaW-IV-VIId  164712   Gadus morhua  Atlantic cod
# 21             CODIS  164712   Gadus morhua  Atlantic cod
# 22            CODKAT  164712   Gadus morhua  Atlantic cod
# 23           CODNEAR  164712   Gadus morhua  Atlantic cod
# 24        CODNEARNCW  164712   Gadus morhua  Atlantic cod
# 25            CODVIa  164712   Gadus morhua  Atlantic cod
# 26            CODVIb  164712   Gadus morhua  Atlantic cod
# 27          CODVIIek  164712   Gadus morhua  Atlantic cod
#
#                               areaid  \
# 0          multinational-ICES-1ABCDE
# 1          multinational-ICES-1F-XIV
# 2             multinational-ICES-1IN
# 3                   Canada-DFO-2J3KL
# 4              multinational-NAFO-3M
# 5             multinational-NAFO-3NO
# 6                  Canada-DFO-3Pn4RS
# 7                     Canada-DFO-3Ps
# 8                      Canada-DFO-4T
# 9                    Canada-DFO-4VsW
# 10                     Canada-DFO-4X
# 11                  Canada-DFO-4X5Yb
# 12           multinational-TRAC-5Zjm
# 13          multinational-ICES-22-24
# 14          multinational-ICES-25-32
# 15            multinational-ICES-Vb2
# 16            multinational-ICES-Vb1
# 17                       USA-NMFS-5Z
# 18                       USA-NMFS-5Y
# 19             multinational-ICES-Va
# 20  multinational-ICES-IIIaW-IV-VIId
# 21           multinational-ICES-VIIa
# 22             multinational-ICES-21
# 23           multinational-ICES-I-II
# 24       multinational-ICES-I-II-NCW
# 25            multinational-ICES-VIa
# 26            multinational-ICES-VIb
# 27         multinational-ICES-VIIe-k
#
#                                             stocklong             region  \
# 0                            Atlantic cod NAFO 1ABCDE  Canada East Coast
# 1                    Atlantic cod NAFO 1F and ICES 14      Europe non EU
# 2               Atlantic cod NAFO Subarea 1 (inshore)  Canada East Coast
# 3   Atlantic cod Southern Labrador-Eastern Newfoun...  Canada East Coast
# 4                            Atlantic cod Flemish Cap  Canada East Coast
# 5                   Atlantic cod Southern Grand Banks  Canada East Coast
# 6          Atlantic cod Northern Gulf of St. Lawrence  Canada East Coast
# 7                        Atlantic cod St. Pierre Bank  Canada East Coast
# 8          Atlantic cod Southern Gulf of St. Lawrence  Canada East Coast
# 9                  Atlantic cod Eastern Scotian Shelf  Canada East Coast
# 10                 Atlantic cod Western Scotian Shelf  Canada East Coast
# 11  Atlantic cod Western Scotian Shelf, Bay of Fun...  Canada East Coast
# 12                             Atlantic cod NAFO 5Zjm  Canada East Coast
# 13                        Atlantic cod Western Baltic     European Union
# 14                        Atlantic cod Eastern Baltic     European Union
# 15                            Atlantic cod Faroe Bank      Europe non EU
# 16                         Atlantic cod Faroe Plateau      Europe non EU
# 17                          Atlantic cod Georges Bank      US East Coast
# 18                         Atlantic cod Gulf of Maine      US East Coast
# 19                       Atlantic cod Iceland Grounds      Europe non EU
# 20                    Atlantic cod ICES 3a(west)-4-7d     European Union
# 21                             Atlantic cod Irish Sea     European Union
# 22                              Atlantic cod Kattegat     European Union
# 23                     Atlantic cod North-East Arctic      Europe non EU
# 24  Atlantic cod North-East Arctic (Norwegian coas...      Europe non EU
# 25                      Atlantic cod West of Scotland     European Union
# 26                          Atlantic cod Rockall Bank     European Union
# 27                            Atlantic cod Celtic Sea     European Union
#
#    primary_country  primary_FAOarea ISO3_code  \
# 0        Greenland               21       GRL
# 1        Greenland               27       GRL
# 2        Greenland               21       GRL
# 3           Canada               21       CAN
# 4         Portugal               21       PRT
# 5            Spain               21       ESP
# 6           Canada               21       CAN
# 7           Canada               21       CAN
# 8           Canada               21       CAN
# 9           Canada               21       CAN
# 10          Canada               21       CAN
# 11          Canada               21       CAN
# 12          Canada               21       CAN
# 13         Denmark               27       DNK
# 14          Poland               27       POL
# 15   Faroe Islands               27       FRO
# 16   Faroe Islands               27       FRO
# 17             USA               21       USA
# 18             USA               21       USA
# 19         Iceland               27       ISL
# 20  United Kingdom               27       GBR
# 21         Ireland               27       IRL
# 22         Denmark               27       DNK
# 23          Norway               27       NOR
# 24          Norway               27       NOR
# 25  United Kingdom               27       GBR
# 26  United Kingdom               27       GBR
# 27          France               27       FRA
#
#                                GRSF_uuid  \
# 0   01203eac-f124-34d5-80c0-44ce978b328e
# 1   269f6c1e-e0cd-3fcb-b2cc-41d338ac824e
# 2   437d0699-5695-336d-b139-bc69de390334
# 3   c9055c35-a306-3a63-83b5-525d9f484840
# 4   ad76fd62-8f75-33d0-82cd-380f9c9f2533
# 5   f8bd5149-f25b-3377-850a-0de697a9bfb9
# 6   5a19ce3d-ecba-3ee1-9f81-c766b3d18d52
# 7   44bdf775-5ab2-36dc-9781-1c5d774d92bd
# 8   f0b7a32d-ba51-3028-941d-e18008450d12
# 9   4e12fcb9-141a-3eef-af10-23f19f4e4f11
# 10  0464895b-495c-3aac-a1e7-95ccd4dc4766
# 11  e8353ac7-d6ca-3f6f-a40d-a95c6dc733a7
# 12  07c88869-539b-36ff-b06e-98d0dbf0fd75
# 13  a210b95c-2012-3c43-929e-c38c4a23f1ab
# 14  52fbf3e6-5141-3233-b8bd-351a5f3bdc40
# 15  a5fdc34f-26ef-340f-a571-bbb0da516e7c
# 16  28b7a713-ba50-3c9f-94d7-7962ebab43df
# 17  71c5f2e5-beaf-3b36-afc7-baf16f0080b7
# 18  0fab3985-c6c0-3851-a1c0-12945c1c18aa
# 19  182f1148-4c60-3b13-a765-21b1b47ead6b
# 20  d2362bce-b855-3367-9c46-c479eeaca2af
# 21  a42e20a7-acac-348f-981e-82c6af35b2c6
# 22  830dbacd-5997-3204-93b4-65f8f77b5170
# 23  d8264317-32db-3758-a373-28ba516a3f86
# 24  b9a1798f-6744-3c76-a207-2584d3293792
# 25  06dbbee6-137d-38d1-9f5d-a27a807fd852
# 26  5fb65e0b-3bf7-3363-a2ed-45d269bc87ec
# 27  43c716ff-3393-3b79-bbe6-b9be78cbc181
#
#                                           GRSF_areaid  inmyersdb myersstockid  \
# 0   fao:21.1.A;fao:21.1.B;fao:21.1.C;fao:21.1.D;fa...          0           NA
# 1                                fao:21.1.F;fao:27.14          0           NA
# 2                                            fao:21.1          0           NA
# 3                    fao:21.2.J;fao:21.3.K;fao:21.3.L          1     COD2J3KL
# 4                                          fao:21.3.M          1        COD3M
# 5                               fao:21.3.N;fao:21.3.O          1       COD3NO
# 6                  fao:21.3.P.n;fao:21.4.R;fao:21.4.S          1    COD3Pn4RS
# 7                                        fao:21.3.P.s          1       COD3Ps
# 8                                          fao:21.4.T          1      COD4TVn
# 9                             fao:21.4.V.s;fao:21.4.W          1      COD4VsW
# 10                                         fao:21.4.X          1        COD4X
# 11                            fao:21.4.X;fao:21.5.Y.b          0           NA
# 12                          fao:21.5.Z.j;fao:21.5.Z.m          0           NA
# 13          fao:27.3.b.23;fao:27.3.c.22;fao:27.3.d.24          1    CODBA2224
# 14  fao:27.3.d.24;fao:27.3.d.25;fao:27.3.d.26;fao:...          1    CODBA2532
# 15                                       fao:27.5.b.2          0           NA
# 16                                       fao:27.5.b.1          1           NA
# 17                                         fao:21.5.Y          1        COD5Z
# 18                                         fao:21.5.Y          0           NA
# 19                                         fao:27.5.a          1       CODICE
# 20       fao:27.3.a;fao:27.3.a.20;fao:27.4;fao:27.7.d          0           NA
# 21                                         fao:27.7.a          1        CODIS
# 22                                      fao:27.3.a.21          1       CODKAT
# 23                                  fao:27.1;fao:27.2          1      CODNEAR
# 24                                  fao:27.1;fao:27.2          0           NA
# 25                                         fao:27.6.a          1       CODVIa
# 26                                         fao:27.6.b          0           NA
# 27  fao:27.7.e;fao:27.7.f;fao:27.7.g;fao:27.7.h;fa...          0           NA
#
#          state
# 0      Current
# 1      Current
# 2      Current
# 3      Current
# 4      Current
# 5      Current
# 6      Current
# 7      Current
# 8      Current
# 9      Current
# 10  Deprecated
# 11     Current
# 12     Current
# 13     Current
# 14     Current
# 15     Current
# 16     Current
# 17     Current
# 18     Current
# 19     Current
# 20     Current
# 21     Current
# 22     Current
# 23     Current
# 24     Current
# 25     Current
# 26     Current
# 27     Current

# %%
timeseries.filter(_.stockid == "COD1ABCDE").head().execute()
# Out:
#                                assessid    stockid                 stocklong  \
# 0  NWWG-COD1ABCDE-1952-2015-ICESIMP2018  COD1ABCDE  Atlantic cod NAFO 1ABCDE
# 1  NWWG-COD1ABCDE-1952-2015-ICESIMP2018  COD1ABCDE  Atlantic cod NAFO 1ABCDE
# 2  NWWG-COD1ABCDE-1952-2015-ICESIMP2018  COD1ABCDE  Atlantic cod NAFO 1ABCDE
# 3  NWWG-COD1ABCDE-1952-2015-ICESIMP2018  COD1ABCDE  Atlantic cod NAFO 1ABCDE
# 4  NWWG-COD1ABCDE-1952-2015-ICESIMP2018  COD1ABCDE  Atlantic cod NAFO 1ABCDE
#
#               tsid  tsyear           tsvalue
# 0  CdivMEANC-ratio    1952  1.31171349447347
# 1  CdivMEANC-ratio    1953  2.01802076072842
# 2  CdivMEANC-ratio    1954  2.99339746174715
# 3  CdivMEANC-ratio    1955  2.70190557408638
# 4  CdivMEANC-ratio    1956   3.3185230287534

# %%
fish = (timeseries
 .rename(tsunique = "tsid")
 .join(tsmetrics,"tsunique")
 .join(stock, ["stockid", "stocklong"])
 .join(assessment,"assessid")
)

cod_catch = (fish
    .filter(_.tscategory == "CATCH or LANDINGS")
    .filter(_.commonname == "Atlantic cod")
)

cod_catch.group_by(_.tslong, _.tsunique).agg(n = _.count()).order_by(_.n.desc()).execute()
# Out:
#                                               tslong         tsunique     n
# 0                        Catch divided by mean catch  CdivMEANC-ratio  7442
# 1    General total Catch (TC then TL, MT units only)        TCbest-MT  7442
# 2                                     Total landings            TL-MT  6278
# 3  Total catch (i.e. landings + discards. Add lan...            TC-MT  4791
# 4          Catch or landings that is paired with TAC         Cpair-MT   347
# 5                              Total allowable catch           TAC-MT   311
# 6                               Catch divided by MSY    CdivMSY-ratio   165
# 7                                 Recreational catch          RecC-MT     8

# %% [markdown]
# # Exercise 1: Investigating the North-Atlantic Cod
#
# Now we are ready to dive into our data. First, We seek to replicate the following figure from the Millennium Ecosystem Assessment Project using the RAM data.
#
# ![](https://espm-157.github.io/website-r/img/cod.jpg)

# %% [markdown]
# # Excersise 2: Global Fisheries
#
# ## Stock Collapses
#
# We seek to replicate the temporal trend in stock declines shown in [Worm et al 2006](http://doi.org/10.1126/science.1132294):
#
# ![](https://espm-157.github.io/website-r/img/worm2006.jpg)
